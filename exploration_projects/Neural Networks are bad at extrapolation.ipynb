# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import explained_variance_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

import matplotlib as mplt
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams["figure.figsize"] = (12,4)

import math
import gc

from datetime import datetime

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
np.set_printoptions(threshold=np.nan)

# %% [markdown]
# ## Training
# - [MLP regressor](http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html)

# %%
x = np.arange(-300,300,0.1)
x = x.reshape(6000,1)
y = np.square(x)
from sklearn.neural_network import MLPRegressor
reg = MLPRegressor(hidden_layer_sizes=(10,10,5,3,),  activation='relu',solver='adam',
               learning_rate='constant', learning_rate_init=0.1, max_iter=1000)

reg = reg.fit(x, y.ravel())

# %%
y_pred = reg.predict(x)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y,y_pred))
# Out:
# 1309.1942604302242

# %%
plt.scatter(x,y,color="green",label='Training Examples')
plt.scatter(x,y_pred,color="red",marker='^',label='Predictions')
plt.xlabel("X value")
plt.ylabel("X^2 actual and trained")
plt.legend()
# Out:
# Text(0.5,0,'X value')
# Text(0,0.5,'X^2 actual and trained')

# %% [markdown]
# ## Interpolation

# %%
x_test = np.arange(-10,10,0.01)
x_test = x_test.reshape(len(x_test),1)
y_test = np.square(x_test)

y_test_pred = reg.predict(x_test)

plt.scatter(x_test,y_test,color="green",label='True Predictions');
plt.scatter(x_test,y_test_pred,color="red",marker='^',label='Extrapolated model Predictions');
plt.xlabel("X value");
plt.ylabel("X^2 actual and Model Predicted");
plt.legend();

np.sqrt(mean_squared_error(y_test,y_test_pred))
# Out:
# Text(0.5,0,'X value')
# Text(0,0.5,'X^2 actual and Model Predicted')
# 47.903178184638435

# %%
x_test = np.arange(100,150,0.1)

x_test = x_test.reshape(len(x_test),1)

y_test = np.square(x_test)

y_test_pred = reg.predict(x_test)

plt.scatter(x_test,y_test,color="green",label='True Predictions')
plt.scatter(x_test,y_test_pred,color="red",marker='^',label='Extrapolated model Predictions')
plt.xlabel("X value")
plt.ylabel("X^2 actual and Model Predicted")
plt.legend()
# Out:
# Text(0.5,0,'X value')
# Text(0,0.5,'X^2 actual and Model Predicted')

# %% [markdown]
# ## Extrapolation

# %%
x_test = np.arange(-600,600,0.1)
x_test = x_test.reshape(len(x_test),1)
y_test = np.square(x_test)

y_test_pred = reg.predict(x_test)

plt.scatter(x_test,y_test,color="green",label='True Predictions')
plt.scatter(x_test,y_test_pred,color="red",marker='^',label='Extrapolated model Predictions')
plt.xlabel("X value")
plt.ylabel("X^2 actual and Model Predicted")
plt.legend()
# Out:
# Text(0.5,0,'X value')
# Text(0,0.5,'X^2 actual and Model Predicted')

# %%
x_test = np.arange(500,1000,0.1)
x_test = x_test.reshape(len(x_test),1)
y_test = np.square(x_test)

y_test_pred = reg.predict(x_test)

plt.scatter(x_test,y_test,color="green",label='True Predictions')
plt.scatter(x_test,y_test_pred,color="red",marker='^',label='Extrapolated model Predictions')
plt.xlabel("X value")
plt.ylabel("X^2 actual and Model Predicted")
plt.legend()
np.sqrt(mean_squared_error(y_test,y_test_pred))
# Out:
# Text(0.5,0,'X value')
# Text(0,0.5,'X^2 actual and Model Predicted')
# 348525.0938038645
